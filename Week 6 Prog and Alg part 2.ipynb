# %%
import pandas as pd

# %%
df=pd.read_csv("Titanic.csv")

# %%
#pd.set_option("max_rows",50)

# %%
#df.style.bar(color="blue",subset=["Age"]).bar(color="green",subset=["Fare"])

# %%
#df

# %%
#Pclass Survived

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df[df["Pclass"]==1]["Survived"].unique()#kolom survived di Pclass 1 tidak ada yang null
# Out:
# array([1, 0], dtype=int64)

# %%
df[df["Pclass"]==1]["Survived"].count() #jumlah yang ada di Pclass 1
# Out:
# 216

# %%
df[df["Pclass"]==1][df["Survived"]==1]["Survived"].count()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 136

# %%
df[df["Pclass"]==1]["Survived"].value_counts() #berapa banyak yang bertahan hidup dan mati, berapa banyak yang ada di dalam pclass1
# Out:
# 1    136
# 0     80
# Name: Survived, dtype: int64

# %%
#["Pclass1","Survived","Death","Survived/total"]

# %%
a=df[df["Survived"]==1][df["Pclass"]==1]["Survived"].count()#mendapatkan yang hidup
b=df[df["Survived"]==0][df["Pclass"]==1]["Survived"].count()#mendapatkan yang meninggal
x=["Pclass1",a,b,a/(a+b)]
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
x=[]

# %%
len(df["Pclass"].value_counts())
# Out:
# 3

# %%
df["Pclass"].nunique()
# Out:
# 3

# %%
x=[]
for i in range(1,len(df["Pclass"].value_counts())+1):
    a=df[df["Survived"]==1][df["Pclass"]==i]["Survived"].count()#mendapatkan yang hidup
    b=df[df["Survived"]==0][df["Pclass"]==i]["Survived"].count()#mendapatkan yang meninggal
    x.append([a,b,a/(a+b)])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
x
# Out:
# [[136, 80, 0.6296296296296297],
#  [87, 97, 0.47282608695652173],
#  [119, 372, 0.24236252545824846]]

# %%
namaindex=['Pclass '+str(i) for i in range(1,len(df["Pclass"].value_counts())+1)]

# %%
df2=pd.DataFrame(x, columns = ['Survived','Death','Percentage'],index=namaindex)

# %%
df2
# Out:
#           Survived  Death  Percentage
# Pclass 1       136     80    0.629630
# Pclass 2        87     97    0.472826
# Pclass 3       119    372    0.242363

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def fun2(columns):
    return "ganti kolom jadi tulisan ini"

# %%
df.apply(fun2)
# Out:
# PassengerId    ganti kolom jadi tulisan ini
# Survived       ganti kolom jadi tulisan ini
# Pclass         ganti kolom jadi tulisan ini
# Name           ganti kolom jadi tulisan ini
# Sex            ganti kolom jadi tulisan ini
# Age            ganti kolom jadi tulisan ini
# SibSp          ganti kolom jadi tulisan ini
# Parch          ganti kolom jadi tulisan ini
# Ticket         ganti kolom jadi tulisan ini
# Fare           ganti kolom jadi tulisan ini
# Cabin          ganti kolom jadi tulisan ini
# Embarked       ganti kolom jadi tulisan ini
# dtype: object

# %%
df.apply(fun2,axis=0)
# Out:
# PassengerId    ganti kolom jadi tulisan ini
# Survived       ganti kolom jadi tulisan ini
# Pclass         ganti kolom jadi tulisan ini
# Name           ganti kolom jadi tulisan ini
# Sex            ganti kolom jadi tulisan ini
# Age            ganti kolom jadi tulisan ini
# SibSp          ganti kolom jadi tulisan ini
# Parch          ganti kolom jadi tulisan ini
# Ticket         ganti kolom jadi tulisan ini
# Fare           ganti kolom jadi tulisan ini
# Cabin          ganti kolom jadi tulisan ini
# Embarked       ganti kolom jadi tulisan ini
# dtype: object

# %%
df["Name"]=df["Name"].apply(fun2)

# %%
df
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 0            1.0       0.0     3.0  ganti kolom jadi tulisan ini    male
# 1            2.0       1.0     1.0  ganti kolom jadi tulisan ini  female
# 2            3.0       1.0     3.0  ganti kolom jadi tulisan ini  female
# 3            NaN       NaN     NaN  ganti kolom jadi tulisan ini     NaN
# 4            5.0       0.0     3.0  ganti kolom jadi tulisan ini    male
# ..           ...       ...     ...                           ...     ...
# 886        887.0       0.0     2.0  ganti kolom jadi tulisan ini    male
# 887        888.0       1.0     1.0  ganti kolom jadi tulisan ini  female
# 888        889.0       0.0     3.0  ganti kolom jadi tulisan ini  female
# 889        890.0       1.0     1.0  ganti kolom jadi tulisan ini    male
# 890        891.0       0.0     3.0  ganti kolom jadi tulisan ini    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.loc[3]=df.apply(fun2,axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 0            1.0       0.0     3.0  ganti kolom jadi tulisan ini    male
# 1            2.0       1.0     1.0  ganti kolom jadi tulisan ini  female
# 2            3.0       1.0     3.0  ganti kolom jadi tulisan ini  female
# 3            NaN       NaN     NaN                           NaN     NaN
# 4            5.0       0.0     3.0  ganti kolom jadi tulisan ini    male
# ..           ...       ...     ...                           ...     ...
# 886        887.0       0.0     2.0  ganti kolom jadi tulisan ini    male
# 887        888.0       1.0     1.0  ganti kolom jadi tulisan ini  female
# 888        889.0       0.0     3.0  ganti kolom jadi tulisan ini  female
# 889        890.0       1.0     1.0  ganti kolom jadi tulisan ini    male
# 890        891.0       0.0     3.0  ganti kolom jadi tulisan ini    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df=pd.read_csv("Titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["PassengerId"]==2]["Fare"]
# Out:
# 1    71.2833
# Name: Fare, dtype: float64

# %%
df[df["PassengerId"]==3]["Fare"]
# Out:
# 2    7.925
# Name: Fare, dtype: float64

# %%
df[df["PassengerId"]==2]["Fare"]>df[df["PassengerId"]==3]["Fare"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-d54c050b0b66> in <module>
# ----> 1 df[df["PassengerId"]==2]["Fare"]>df[df["PassengerId"]==3]["Fare"]
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1140
#    1141         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1142             raise ValueError("Can only compare identically-labeled " "Series objects")
#    1143
#    1144         elif is_categorical_dtype(self):
#
# ValueError: Can only compare identically-labeled Series objects

# %%
df[df["PassengerId"]==2]["Fare"][1]>df[df["PassengerId"]==3]["Fare"][2]
# Out:
# True

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Survived"]==1][df["Pclass"]==2]["Survived"].count()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 87
