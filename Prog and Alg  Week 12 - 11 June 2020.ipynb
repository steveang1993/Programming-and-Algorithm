# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\File Steven\Lecture\Prasmul\2. Even 2020\Programming and Algorithm\Dataset in LMS\tips.csv")

# %%
df
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
#tip terbanyak ada di hari apa.

# %%
dfg=df.groupby(["day"]).agg({'tip':['mean']})

# %%
dfg
# Out:
#            tip
#           mean
# day
# Fri   2.734737
# Sat   2.993103
# Sun   3.255132
# Thur  2.771452

# %%
dfg.plot.pie(y='tip')

# %%
dfg.plot.bar()

# %%
dfg.sort_values(by=["day"],ascending=False)
# Out:
#            tip
#           mean
# day
# Thur  2.771452
# Sun   3.255132
# Sat   2.993103
# Fri   2.734737

# %%
daytoint={'Thur':1,'Fri':2,'Sat':3,'Sun':4}
dfg['daynum']=dfg.index.map(daytoint)

# %%
dfg
# Out:
#            tip daynum
#           mean
# day
# Fri   2.734737      2
# Sat   2.993103      3
# Sun   3.255132      4
# Thur  2.771452      1

# %%
dfg=dfg.sort_values(by=['daynum'])

# %%
dfg=dfg.drop(["daynum"],axis=1)

# %%
dfg
# Out:
#            tip
#           mean
# day
# Thur  2.771452
# Fri   2.734737
# Sat   2.993103
# Sun   3.255132

# %%
dfg.plot.bar()

# %%
df.plot.bar(figsize=(60,30))

# %%
df
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
dfg=df.groupby(["size"]).agg({'size':['count']})

# %%
dfg
# Out:
#       size
#      count
# size
# 1        4
# 2      156
# 3       38
# 4       37
# 5        5
# 6        4

# %%
dfg.plot.bar()

# %%
fig=dfg.plot.pie(y='size')

# %%
df=pd.read_csv(r"C:\File Steven\Lecture\Prasmul\2. Even 2020\Programming and Algorithm\Dataset in LMS\vgsales.csv",index_col=0)

# %%
df
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
df['Year'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000.,   nan, 1995., 2016., 1991., 1981., 1987.,
#        1980., 1983., 2020., 2017.])

# %%
df=df.dropna()

# %%
dfg=df.groupby(["Platform"]).agg('sum')

# %%
dfg=dfg.drop(["Year","Global_Sales"],axis=1)

# %%
dfg.plot.bar(figsize=(60,30),stacked=True)

# %%
import seaborn as sns

# %%
sns.barplot(data=dfg,orient='v')

# %%
dfg.describe()
# Out:
#          NA_Sales    EU_Sales    JP_Sales  Other_Sales
# count   31.000000   31.000000   31.000000    31.000000
# mean   139.601613   77.635161   41.428065    25.448710
# std    175.509722  104.840229   51.137704    44.590561
# min      0.000000    0.000000    0.000000     0.000000
# 25%      3.215000    1.115000    0.915000     0.170000
# 50%     83.190000   38.320000   14.300000     6.450000
# 75%    158.670000   98.095000   77.550000    32.510000
# max    594.330000  340.470000  175.020000   190.470000

# %%
df
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
#sns.barplot(data=df[["NA_Sales","EU_Sales","JP_Sales","Other_Sales"]],orient='v')
df=df.dropna()
df
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
graph=sns.barplot(x='Genre',y='NA_Sales',data=df,orient='v')

# %%
graph.set_xticklabels(graph.get_xticklabels(),rotation=45)
# Out:
# [Text(0, 0, 'Sports'),
#  Text(1, 0, 'Platform'),
#  Text(2, 0, 'Racing'),
#  Text(3, 0, 'Role-Playing'),
#  Text(4, 0, 'Puzzle'),
#  Text(5, 0, 'Misc'),
#  Text(6, 0, 'Shooter'),
#  Text(7, 0, 'Simulation'),
#  Text(8, 0, 'Action'),
#  Text(9, 0, 'Fighting'),
#  Text(10, 0, 'Adventure'),
#  Text(11, 0, 'Strategy')]

# %%
# %matplotlib inline
graph

# %%
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
graph=sns.barplot(x='Genre',y='NA_Sales',data=df,orient='v')
graph.set_xticklabels(graph.get_xticklabels(),rotation=90)
graph

# %%
dfg
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Platform
# 2600         80.78      4.86      0.00         0.84
# 3DO           0.00      0.00      0.10         0.00
# 3DS          78.03     58.29     97.30        12.55
# DC            5.43      1.69      8.56         0.27
# DS          388.53    194.05    175.02        60.29
# GB          113.64     47.51     85.12         8.16
# GBA         178.43     72.49     46.56         7.51
# GC          131.94     38.32     21.34         5.13
# GEN          19.27      5.52      2.67         0.89
# GG            0.00      0.00      0.04         0.00
# N64         138.91     41.03     33.76         4.31
# NES         125.94     21.15     98.65         5.31
# NG            0.00      0.00      1.44         0.00
# PC           92.04    137.35      0.17        24.33
# PCFX          0.00      0.00      0.03         0.00
# PS          334.71    212.38    139.78        40.69
# PS2         572.92    332.63    137.54       190.47
# ...

# %%
dfg['NA_Sales'].plot.density()

# %%
dfg['JP_Sales'].plot.density()

# %%
dfg=df.groupby("Platform",as_index=False).agg('sum')
dfg
# Out:
#    Platform       Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0      2600   229928.0     80.78      4.86      0.00         0.84
# 1       3DO     5984.0      0.00      0.00      0.10         0.00
# 2       3DS  1004517.0     78.03     58.29     97.30        12.55
# 3        DC   103997.0      5.43      1.69      8.56         0.27
# 4        DS  4279469.0    388.53    194.05    175.02        60.29
# 5        GB   193608.0    113.64     47.51     85.12         8.16
# 6       GBA  1574496.0    178.43     72.49     46.56         7.51
# 7        GC  1085843.0    131.94     38.32     21.34         5.13
# 8       GEN    53812.0     19.27      5.52      2.67         0.89
# 9        GG     1992.0      0.00      0.00      0.04         0.00
# 10      N64   631536.0    138.91     41.03     33.76         4.31
# 11      NES   194741.0    125.94     21.15     98.65         5.31
# 12       NG    23934.0      0.00      0.00      1.44         0.00
# ...

# %%
dfg.plot.scatter(x="Platform",y="JP_Sales")

# %%
dfg['JP_Sales'].plot.density()

# %%
sns.distplot(dfg["NA_Sales"],color='b')

# %%
df=pd.read_csv(r"C:\File Steven\Lecture\Prasmul\2. Even 2020\Programming and Algorithm\Dataset in LMS\Titanic.csv",index_col=0)

# %%
df=df.dropna()
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %%
sns.factorplot(x='Pclass',y='Age',row='Survived',col='Sex',kind='box',data=df)

# %%
plt.figure(figsize=(10,10))         # Sample figsize in inches
sns.heatmap(df.corr())

# %%
#df.corr()

# %%
#aij =aji

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %%
a=df["Age"]

# %%
df.boxplot(column=['Age'])

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  183.000000  183.000000  183.000000  183.000000  183.000000  183.000000
# mean     0.672131    1.191257   35.674426    0.464481    0.475410   78.682469
# std      0.470725    0.515187   15.643866    0.644159    0.754617   76.347843
# min      0.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   24.000000    0.000000    0.000000   29.700000
# 50%      1.000000    1.000000   36.000000    0.000000    0.000000   57.000000
# 75%      1.000000    1.000000   47.500000    1.000000    1.000000   90.000000
# max      1.000000    3.000000   80.000000    3.000000    4.000000  512.329200
