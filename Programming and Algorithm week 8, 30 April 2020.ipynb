# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\Top companies ver3.csv",na_values=['NONE','Nothing','None','Null'],index_col=0)

# %%
df
# Out:
#                             Name                     Industry    Revenue  \
# Rank
# 1                        Walmart                       Retail  $514,405
# 2                        Sinopec                  Oil and gas  $414,649
# 3              Royal Dutch Shell                  Oil and gas  $396,556
# 4       China National Petroleum                  Oil and gas  $392,976
# 5                     State Grid                  Electricity  $387,056
# 6                   Saudi Aramco                  Oil and gas  $355,905
# 7                             BP                  Oil and gas  $303,738
# 8                     ExxonMobil                  Oil and gas  $290,212
# 9                     Volkswagen                          NaN  $278,341
# 10                        Toyota                   Automotive  $272,612
# 11                         Apple                  Electronics  $265,595
# 12            Berkshire Hathaway                   Financials  $247,837
# ...

# %%
df.isnull().sum()
# Out:
# Name         2
# Industry     4
# Revenue      3
# Profit       1
# Employees    1
# Country      1
# Date         1
# dtype: int64

# %%
df.dropna()
# Out:
#                             Name                     Industry    Revenue  \
# Rank
# 1                        Walmart                       Retail  $514,405
# 2                        Sinopec                  Oil and gas  $414,649
# 3              Royal Dutch Shell                  Oil and gas  $396,556
# 4       China National Petroleum                  Oil and gas  $392,976
# 5                     State Grid                  Electricity  $387,056
# 6                   Saudi Aramco                  Oil and gas  $355,905
# 7                             BP                  Oil and gas  $303,738
# 8                     ExxonMobil                  Oil and gas  $290,212
# 10                        Toyota                   Automotive  $272,612
# 11                         Apple                  Electronics  $265,595
# 12            Berkshire Hathaway                   Financials  $247,837
# 13                        Amazon                       Retail  $232,887
# ...

# %%
df2=df.drop(['Industry',"Date"],axis=1)

# %%
df2
# Out:
#                             Name    Revenue     Profit  Employees  \
# Rank
# 1                        Walmart  $514,405      $6,670  2,200,000
# 2                        Sinopec  $414,649      $5,845    619.151
# 3              Royal Dutch Shell  $396,556     $23,352         81
# 4       China National Petroleum  $392,976      $2,270  1,382,401
# 5                     State Grid  $387,056      $8,174    917.717
# 6                   Saudi Aramco  $355,905    $110,974     76.418
# 7                             BP  $303,738      $9,383          5
# 8                     ExxonMobil  $290,212     $20,840         71
# 9                     Volkswagen  $278,341     $14,332    664.496
# 10                        Toyota  $272,612     $16,982     370.87
# 11                         Apple  $265,595     $59,531        132
# 12            Berkshire Hathaway  $247,837      $4,021        389
# 13                        Amazon  $232,887     $10,073        647
# ...

# %%
df2.dropna(subset=['Profit'])
# Out:
#                             Name    Revenue     Profit  Employees  \
# Rank
# 1                        Walmart  $514,405      $6,670  2,200,000
# 2                        Sinopec  $414,649      $5,845    619.151
# 3              Royal Dutch Shell  $396,556     $23,352         81
# 4       China National Petroleum  $392,976      $2,270  1,382,401
# 5                     State Grid  $387,056      $8,174    917.717
# 6                   Saudi Aramco  $355,905    $110,974     76.418
# 7                             BP  $303,738      $9,383          5
# 8                     ExxonMobil  $290,212     $20,840         71
# 9                     Volkswagen  $278,341     $14,332    664.496
# 10                        Toyota  $272,612     $16,982     370.87
# 11                         Apple  $265,595     $59,531        132
# 12            Berkshire Hathaway  $247,837      $4,021        389
# 13                        Amazon  $232,887     $10,073        647
# ...

# %%
df2.isnull().sum()
# Out:
# Name         2
# Revenue      3
# Profit       1
# Employees    1
# Country      1
# dtype: int64

# %%
df2['Country'][31]='China'

# %%
df2
# Out:
#                             Name    Revenue     Profit  Employees  \
# Rank
# 1                        Walmart  $514,405      $6,670  2,200,000
# 2                        Sinopec  $414,649      $5,845    619.151
# 3              Royal Dutch Shell  $396,556     $23,352         81
# 4       China National Petroleum  $392,976      $2,270  1,382,401
# 5                     State Grid  $387,056      $8,174    917.717
# 6                   Saudi Aramco  $355,905    $110,974     76.418
# 7                             BP  $303,738      $9,383          5
# 8                     ExxonMobil  $290,212     $20,840         71
# 9                     Volkswagen  $278,341     $14,332    664.496
# 10                        Toyota  $272,612     $16,982     370.87
# 11                         Apple  $265,595     $59,531        132
# 12            Berkshire Hathaway  $247,837      $4,021        389
# 13                        Amazon  $232,887     $10,073        647
# ...

# %%
import numpy as np

# %%
df2['Country'][31]=np.nan

# %%
df2
# Out:
#                             Name    Revenue     Profit  Employees  \
# Rank
# 1                        Walmart  $514,405      $6,670  2,200,000
# 2                        Sinopec  $414,649      $5,845    619.151
# 3              Royal Dutch Shell  $396,556     $23,352         81
# 4       China National Petroleum  $392,976      $2,270  1,382,401
# 5                     State Grid  $387,056      $8,174    917.717
# 6                   Saudi Aramco  $355,905    $110,974     76.418
# 7                             BP  $303,738      $9,383          5
# 8                     ExxonMobil  $290,212     $20,840         71
# 9                     Volkswagen  $278,341     $14,332    664.496
# 10                        Toyota  $272,612     $16,982     370.87
# 11                         Apple  $265,595     $59,531        132
# 12            Berkshire Hathaway  $247,837      $4,021        389
# 13                        Amazon  $232,887     $10,073        647
# ...

# %%
df2['Country'][df2['Name']=='China Construction Bank']='China'

# %%
df2
# Out:
#                             Name    Revenue     Profit  Employees  \
# Rank
# 1                        Walmart  $514,405      $6,670  2,200,000
# 2                        Sinopec  $414,649      $5,845    619.151
# 3              Royal Dutch Shell  $396,556     $23,352         81
# 4       China National Petroleum  $392,976      $2,270  1,382,401
# 5                     State Grid  $387,056      $8,174    917.717
# 6                   Saudi Aramco  $355,905    $110,974     76.418
# 7                             BP  $303,738      $9,383          5
# 8                     ExxonMobil  $290,212     $20,840         71
# 9                     Volkswagen  $278,341     $14,332    664.496
# 10                        Toyota  $272,612     $16,982     370.87
# 11                         Apple  $265,595     $59,531        132
# 12            Berkshire Hathaway  $247,837      $4,021        389
# 13                        Amazon  $232,887     $10,073        647
# ...

# %%
df2.loc[df2['Name']=='China Construction Bank','Country']='China'

# %%
df2
# Out:
#                             Name    Revenue     Profit  Employees  \
# Rank
# 1                        Walmart  $514,405      $6,670  2,200,000
# 2                        Sinopec  $414,649      $5,845    619.151
# 3              Royal Dutch Shell  $396,556     $23,352         81
# 4       China National Petroleum  $392,976      $2,270  1,382,401
# 5                     State Grid  $387,056      $8,174    917.717
# 6                   Saudi Aramco  $355,905    $110,974     76.418
# 7                             BP  $303,738      $9,383          5
# 8                     ExxonMobil  $290,212     $20,840         71
# 9                     Volkswagen  $278,341     $14,332    664.496
# 10                        Toyota  $272,612     $16,982     370.87
# 11                         Apple  $265,595     $59,531        132
# 12            Berkshire Hathaway  $247,837      $4,021        389
# 13                        Amazon  $232,887     $10,073        647
# ...

# %%
df2.replace(to_replace=np.nan,value=0)
# Out:
#                             Name    Revenue     Profit  Employees  \
# Rank
# 1                        Walmart  $514,405      $6,670  2,200,000
# 2                        Sinopec  $414,649      $5,845    619.151
# 3              Royal Dutch Shell  $396,556     $23,352         81
# 4       China National Petroleum  $392,976      $2,270  1,382,401
# 5                     State Grid  $387,056      $8,174    917.717
# 6                   Saudi Aramco  $355,905    $110,974     76.418
# 7                             BP  $303,738      $9,383          5
# 8                     ExxonMobil  $290,212     $20,840         71
# 9                     Volkswagen  $278,341     $14,332    664.496
# 10                        Toyota  $272,612     $16,982     370.87
# 11                         Apple  $265,595     $59,531        132
# 12            Berkshire Hathaway  $247,837      $4,021        389
# 13                        Amazon  $232,887     $10,073        647
# ...

# %%
df=df2

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\Top companies ver3.csv",na_values=['NONE','Nothing','None','Null'],index_col=0)

# %%
df2=df

# %%
df2
# Out:
#                             Name                     Industry    Revenue  \
# Rank
# 1                        Walmart                       Retail  $514,405
# 2                        Sinopec                  Oil and gas  $414,649
# 3              Royal Dutch Shell                  Oil and gas  $396,556
# 4       China National Petroleum                  Oil and gas  $392,976
# 5                     State Grid                  Electricity  $387,056
# 6                   Saudi Aramco                  Oil and gas  $355,905
# 7                             BP                  Oil and gas  $303,738
# 8                     ExxonMobil                  Oil and gas  $290,212
# 9                     Volkswagen                          NaN  $278,341
# 10                        Toyota                   Automotive  $272,612
# 11                         Apple                  Electronics  $265,595
# 12            Berkshire Hathaway                   Financials  $247,837
# ...

# %%
df2["Revenue"].fillna(0, inplace = True)

# %%
df2
# Out:
#                             Name                     Industry    Revenue  \
# Rank
# 1                        Walmart                       Retail  $514,405
# 2                        Sinopec                  Oil and gas  $414,649
# 3              Royal Dutch Shell                  Oil and gas  $396,556
# 4       China National Petroleum                  Oil and gas  $392,976
# 5                     State Grid                  Electricity  $387,056
# 6                   Saudi Aramco                  Oil and gas  $355,905
# 7                             BP                  Oil and gas  $303,738
# 8                     ExxonMobil                  Oil and gas  $290,212
# 9                     Volkswagen                          NaN  $278,341
# 10                        Toyota                   Automotive  $272,612
# 11                         Apple                  Electronics  $265,595
# 12            Berkshire Hathaway                   Financials  $247,837
# ...

# %%
df2=df

# %%
add=df.loc[50]

# %%
add
# Out:
# Name              Lukoil
# Industry     Oil and gas
# Revenue        $119,145
# Profit            $9,863
# Employees          102.5
# Country           Russia
# Date           4/21/2018
# Name: 50, dtype: object

# %%
df2=df2.append(add)

# %%
df2
# Out:
#                             Name                     Industry    Revenue  \
# Rank
# 1                        Walmart                       Retail  $514,405
# 2                        Sinopec                  Oil and gas  $414,649
# 3              Royal Dutch Shell                  Oil and gas  $396,556
# 4       China National Petroleum                  Oil and gas  $392,976
# 5                     State Grid                  Electricity  $387,056
# 6                   Saudi Aramco                  Oil and gas  $355,905
# 7                             BP                  Oil and gas  $303,738
# 8                     ExxonMobil                  Oil and gas  $290,212
# 9                     Volkswagen                          NaN  $278,341
# 10                        Toyota                   Automotive  $272,612
# 11                         Apple                  Electronics  $265,595
# 12            Berkshire Hathaway                   Financials  $247,837
# ...

# %%
df2=df2.append(add)
df2=df2.append(add)
df2=df2.append(add)
df2=df2.append(add)

# %%
df2
# Out:
#                             Name                     Industry    Revenue  \
# Rank
# 1                        Walmart                       Retail  $514,405
# 2                        Sinopec                  Oil and gas  $414,649
# 3              Royal Dutch Shell                  Oil and gas  $396,556
# 4       China National Petroleum                  Oil and gas  $392,976
# 5                     State Grid                  Electricity  $387,056
# 6                   Saudi Aramco                  Oil and gas  $355,905
# 7                             BP                  Oil and gas  $303,738
# 8                     ExxonMobil                  Oil and gas  $290,212
# 9                     Volkswagen                          NaN  $278,341
# 10                        Toyota                   Automotive  $272,612
# 11                         Apple                  Electronics  $265,595
# 12            Berkshire Hathaway                   Financials  $247,837
# ...

# %%
df2.duplicated()
# Out:
# Rank
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 50     True
# 50     True
# 50     True
# 50     True
# 50     True
# dtype: bool

# %%
df2["Industry"].duplicated()
# Out:
# Rank
# 1     False
# 2     False
# 3      True
# 4      True
# 5     False
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15     True
# 16    False
# 17     True
# 18     True
# 19     True
# 20     True
# 21    False
# 22     True
# 23     True
# 24     True
# 25    False
# 26     True
# 27    False
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33    False
# 34     True
# 35     True
# 36     True
# 37    False
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# 50     True
# 50     True
# 50     True
# 50     True
# 50     True
# 50     True
# Name: Industry, dtype: bool

# %%
df2
# Out:
#                             Name                     Industry    Revenue  \
# Rank
# 1                        Walmart                       Retail  $514,405
# 2                        Sinopec                  Oil and gas  $414,649
# 3              Royal Dutch Shell                  Oil and gas  $396,556
# 4       China National Petroleum                  Oil and gas  $392,976
# 5                     State Grid                  Electricity  $387,056
# 6                   Saudi Aramco                  Oil and gas  $355,905
# 7                             BP                  Oil and gas  $303,738
# 8                     ExxonMobil                  Oil and gas  $290,212
# 9                     Volkswagen                          NaN  $278,341
# 10                        Toyota                   Automotive  $272,612
# 11                         Apple                  Electronics  $265,595
# 12            Berkshire Hathaway                   Financials  $247,837
# ...

# %%
df2.drop_duplicates()
# Out:
#                             Name                     Industry    Revenue  \
# Rank
# 1                        Walmart                       Retail  $514,405
# 2                        Sinopec                  Oil and gas  $414,649
# 3              Royal Dutch Shell                  Oil and gas  $396,556
# 4       China National Petroleum                  Oil and gas  $392,976
# 5                     State Grid                  Electricity  $387,056
# 6                   Saudi Aramco                  Oil and gas  $355,905
# 7                             BP                  Oil and gas  $303,738
# 8                     ExxonMobil                  Oil and gas  $290,212
# 9                     Volkswagen                          NaN  $278,341
# 10                        Toyota                   Automotive  $272,612
# 11                         Apple                  Electronics  $265,595
# 12            Berkshire Hathaway                   Financials  $247,837
# ...

# %%
df2=df2.drop_duplicates()

# %%
df2
# Out:
#                             Name                     Industry    Revenue  \
# Rank
# 1                        Walmart                       Retail  $514,405
# 2                        Sinopec                  Oil and gas  $414,649
# 3              Royal Dutch Shell                  Oil and gas  $396,556
# 4       China National Petroleum                  Oil and gas  $392,976
# 5                     State Grid                  Electricity  $387,056
# 6                   Saudi Aramco                  Oil and gas  $355,905
# 7                             BP                  Oil and gas  $303,738
# 8                     ExxonMobil                  Oil and gas  $290,212
# 9                     Volkswagen                          NaN  $278,341
# 10                        Toyota                   Automotive  $272,612
# 11                         Apple                  Electronics  $265,595
# 12            Berkshire Hathaway                   Financials  $247,837
# ...

# %%
x=[51,"New","Oil and Gas","#$150,000","$5,000",7.1,"Indonesia","1/1/2020"]

# %%
df2=df

# %%
df.loc[50]
# Out:
# Name              Lukoil
# Industry     Oil and gas
# Revenue        $119,145
# Profit            $9,863
# Employees          102.5
# Country           Russia
# Date           4/21/2018
# Name: 50, dtype: object

# %%
type(df.loc[50])
# Out:
# pandas.core.series.Series

# %%
x=pd.Series(x)

# %%
df2=df

# %%
x=[51,"New","Oil and Gas","#$150,000","$5,000",7.1,"Indonesia","1/1/2020"]

# %%
df2=list(df2) #Gagal

# %%
df2.append(x)

# %%
df2=list(df)

# %%
df2=df

# %%
x=["New","Oil and Gas","#$150,000","$5,000",7.1,"Indonesia","1/1/2020"]

# %%
df2.loc[51]=x

# %%
df2["id"]=[i for i in range(101,100+len(df2)+1)]

# %%
df2
# Out:
#                             Name                     Industry    Revenue  \
# Rank
# 1                        Walmart                       Retail  $514,405
# 2                        Sinopec                  Oil and gas  $414,649
# 3              Royal Dutch Shell                  Oil and gas  $396,556
# 4       China National Petroleum                  Oil and gas  $392,976
# 5                     State Grid                  Electricity  $387,056
# 6                   Saudi Aramco                  Oil and gas  $355,905
# 7                             BP                  Oil and gas  $303,738
# 8                     ExxonMobil                  Oil and gas  $290,212
# 9                     Volkswagen                          NaN  $278,341
# 10                        Toyota                   Automotive  $272,612
# 11                         Apple                  Electronics  $265,595
# 12            Berkshire Hathaway                   Financials  $247,837
# ...

# %%
x=["New2","Oil and Gas","#$150,000","$5,000",7.1,"Indonesia","1/1/2020",df2["id"][len(df2)]+1]

# %%
x
# Out:
# ['New2',
#  'Oil and Gas',
#  '#$150,000',
#  '$5,000',
#  7.1,
#  'Indonesia',
#  '1/1/2020',
#  152]

# %%
#Kolom : Male/Female->0/1
#Sangat setuju, Tidak Setuju, Setuju, Sangat Tidak Setuju
#Sangat Setuju, Setuju, Tidak Setuju, Sangat Tidak Setuju->1,2,3,4 atau 4,3,2,1

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\Titanic.csv",na_values=['NONE','Nothing','None','Null'],index_col=0)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df[df["Sex"]=="male"]["Sex"]=1
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.loc[df["Sex"]=="male","Sex"]=1
df.loc[df["Sex"]=="female","Sex"]=0

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\Titanic.csv",na_values=['NONE','Nothing','None','Null'],index_col=0)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.replace({'Sex':{'male':1,'female':0}})
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
# ...                                                        ...  ...   ...
# ...

# %%
df.replace({'Sex':{'male':1,'female':0},'Embarked':{'S':'Solo'}})
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
# ...                                                        ...  ...   ...
# ...

# %%
df.replace({'Sex':{'male':1,'female':0}})
df.replace({'Embarked':{'S':'Solo','C':'Cirebon'}})
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df[df['Sex']=='male']=1

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   1       1
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   1       1
# ...               ...     ...
# 887                 1       1
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                                            1       1   1.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                                            1       1   1.0
# ...                                                        ...     ...   ...
# ...

# %%
df.loc[:,df.columns!='Cabin']
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   1       1
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   1       1
# ...               ...     ...
# 887                 1       1
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                                            1       1   1.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                                            1       1   1.0
# ...                                                        ...     ...   ...
# ...
